# %%
name = str(input("Enter name"))
address = str(input("Enter address"))
contact = int(input("Enter contact number"))
mtongue = str(input("Enter mother tongue"))
school = str(input("Enter school name"))
year = str(input("Enter your year"))
panel = str(input("Enter the panel"))
roll = str(input("Enter your roll number"))

print("Student name:" , name)
print("Address:" , address)
print("Contact number:" , contact)
print("Mother Tongue:" , mtongue)
print("School name:" , school)
print("The year is:" , year)
print("The panel is:" , panel)
print("The roll number:" , roll)
# Out:
# Enter name Aayush
# Enter address HIvise road
# Enter contact number 98566397279
# Enter mother tongue Hindi
# Enter school name MIT WPU
# Enter your year 2026
# Enter the panel CSe
# Enter your roll number 038232752
# Student name: Aayush
# Address: HIvise road
# Contact number: 98566397279
# Mother Tongue: Hindi
# School name: MIT WPU
# The year is: 2026
# The panel is: CSe
# The roll number: 038232752

# %%
name = str(input("Enter name"))
address = str(input("Enter address"))
contact = int(input("Enter contact number"))
mtongue = str(input("Enter mother tongue"))
school = str(input("Enter school name"))
year = str(input("Enter your year"))
panel = str(input("Enter the panel"))
roll = str(input("Enter your roll number"))

print("Student name:" , name)
"""
print("Address:" , address)
print("Contact number:" , contact)
print("Mother Tongue:" , mtongue)
"""
print("School name:" , school)
print("The year is:" , year)
print("The panel is:" , panel)
print("The roll number:" , roll)
# Out:
# Enter name Aayush
# Enter address Hivise road
# Enter contact number 91340234
# Enter mother tongue Hindi
# Enter school name BLUe
# Enter your year 2026
# Enter the panel Cse
# Enter your roll number 136936934
# Student name: Aayush
# School name: BLUe
# The year is: 2026
# The panel is: Cse
# The roll number: 136936934

# %%
student = str(input("Enter name:"))
roll = int(input("Enter roll number"))

maths = float(input("Enter maths marks:"))
chem = float(input("Enter chemistry marks:"))
phy = float(input("Enter physics marks:"))

avg = (maths+chem+phy)/3
print("Average:" , avg)

larg=0.0
small=0.0

if maths==chem and maths==phy:
    larg=maths
    print("All three subjects have equal marks of" , larg)

elif maths==chem and maths>phy:
    larg=maths
    small=phy
    print("Maths and Chemistry are equal and are highest with" , larg , "marks")
    print("Subject with lowest marks is Physics with" , small , "marks")

elif phy==chem and maths<phy:
    larg=phy
    small=maths
    print("Physics and Chemistry are equal and are highest with" , larg , "marks")
    print("Subject with lowest marks is Maths with" , small , "marks")

elif phy==maths and maths>chem:
    larg=phy
    small=chem
    print("Physics and Maths are equal and are highest with" , larg , "marks")
    print("Subject with lowest marks is Chemistry with" , small , "marks")

elif maths>phy and maths>chem:
    larg=maths
    print("Maths is highest with" , larg , "marks")
    
    if phy>chem:
        small=chem
        print("Chemistry is lowest with" , small , "marks")
    else:
        small=phy
        print("Physics is lowest with" , small , "marks")
        
elif phy>maths and phy>chem:
    larg=phy
    print("Physics is highest with" , larg , "marks")
    
    if math>chem:
        small=chem
        print("Chemistry is lowest with" , small , "marks")
    else:
        small=maths
        print("Maths is lowest with" , small , "marks")
        
elif chem>maths and chem>phy:
    larg=chem
    print("Chemistry is highest with" , larg , "marks")
    
    if phy<maths:
        small=phy
        print("Physics is lowest with" , small , "marks")
    else:
        small=maths
        print("Maths is lowest with" , small , "marks")
# Out:
# Enter name: Aayush
# Enter roll number 24795923
# Enter maths marks: 99.99
# Enter chemistry marks: 95.68
# Enter physics marks: 93.54
# Average: 96.40333333333335
# Maths is highest with 99.99 marks
# Physics is lowest with 93.54 marks
